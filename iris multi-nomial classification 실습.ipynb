# %%
# iris multi-nomial classification 실습

import tensorflow as tf
import numpy as np
tf.random.set_seed(5)

xy = np.loadtxt('iris.csv', delimiter=',', dtype=np.str, skiprows=1)
xy.shape     # (151, 6)

# 학습 데이터 분리 : 70% , 105개

x_train = np.float32(xy[:35,1:-1])
x_train = np.append(x_train, np.float32(xy[50:85,1:-1]),0)
x_train = np.append(x_train, np.float32(xy[100:135,1:-1]),0)  # (105,4)
y_train = xy[:105,[-1]]

print(x_train.shape)    # (70, 16)
print(y_train.shape)    # (70, 1)

# 검증 데이터 분리 : 30% , 46개

x_test = np.float32(xy[35:50,1:-1])
x_test = np.append(x_train, np.float32(xy[85:100,1:-1]),0)
x_test = np.append(x_train, np.float32(xy[135:,1:-1]),0)
y_test = xy[105:,[-1]]

print(x_test.shape)    # (31, 16)
print(y_test.shape)    # (31, 1)
# Out:
# (105, 4)
# (105, 1)
# (120, 4)
# (45, 1)

# %%
x_test
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...
